# %% [markdown]
# This notebook is used to calculate GLSZM properties to infer sGREV.

# %%
# Import all the libraries
from __future__ import print_function
import os
import collections
import SimpleITK as sitk
import numpy as np
import six
import radiomics
from radiomics import firstorder, glcm, imageoperations, shape, glrlm, glszm, getTestCase
import sys
import logging as logger
import time
import json
import os
import logging.config
import pandas as pd
import gc
import math

# %% [markdown]
# #### Functions to be used

# %%
def max_min_glszm_window():
    
    df_min = my_df.min(axis=0).to_frame()
    df_min = df_min.rename(index = str, columns={0: "Minimum"})

    df_max = my_df.max(axis=0).to_frame()
    df_max = df_max.rename(index = str, columns={0: "Maximum"})

    df_max_min = df_min.merge(df_max, how='outer', left_index=True, right_index=True)
    
    name_min_max_csv = 'glszm_img_{}_w{}_min_max.csv'.format(num_img, window_size)
    df_max_min.to_csv(name_min_max_csv, index=True, header=True)
    
    del df_min, df_max, df_max_min

# %%
def glszm_calculations():
    "compute all the GLSZM related parameters"
    
    import radiomics
    from radiomics import firstorder, glcm, imageoperations, shape, glrlm, glszm, getTestCase
    #calculate the original glszm
    glszmFeatures = glszm.RadiomicsGLSZM(croppedImage, croppedMask, **settings)
    glszmFeatures.enableAllFeatures()
    result = glszmFeatures.execute()

    print("Calculated GLSZM.....")

    glszm_org = glszmFeatures.P_glszm
    #The graylevels in original ROI after discretization
    graylevels_org = glszmFeatures.coefficients['grayLevels']

    #vector of all the gray-level valus present in the original ROI
    im_exp = sitk.GetArrayFromImage(croppedImage)
    iv_org =  np.unique(im_exp)#glszmFeatures.coefficients['ivector']
    iv_org = iv_org.astype(float)
    #print(str(iv_org))
    iv_org = iv_org + 1
    #print(str(iv_org))

    #vector of all the size zones in the original GLSZM
    jv_org = glszmFeatures.coefficients['jvector']

    # sum of all the size zones for all the graylevels of a particular size zones
    # for every column of GLSZM, add all the rows
    ps_org = glszmFeatures.coefficients['ps']

    #Remove the mineral or saturated phase if it exists FROM GLSZM
    if iv_org[iv_org.size - 1] == 256:
        print('Mineral phase is present because the graylevel of', iv_org[iv_org.size-1], 'exists.')
        mineralGrayLevels_idx = iv_org.size-1
        #Calculate the new GLSZM
        glszm_no_mineral = np.delete(glszm_org, mineralGrayLevels_idx, 1)
        s_nm = glszm_no_mineral.shape

        #Calculate the new ivector
        iv_new = iv_org[0:iv_org.size-1]  # shape (Ng,)

        #Calculate the new ps array with zero values
        glszm_2d_nm = glszm_no_mineral[0, 0:s_nm[1], 0:s_nm[2]]
        ps_new_zeros = np.sum(glszm_2d_nm, 0)
        ps_reshape = np.reshape(ps_new_zeros, (1,s_nm[2]))

        #Delete columns that specify zone sizes not present in the ROI
        emptyZoneSizes = np.where(np.sum(ps_reshape, 0) == 0)
        glszm_new = np.delete(glszm_no_mineral, emptyZoneSizes, 2)
        s_new = glszm_new.shape
        jv_new = np.delete(jv_org, emptyZoneSizes)
        ps_new = np.delete(ps_org, emptyZoneSizes, 1)

        # Get the number of zones in this GLSZM
        Nz_new = np.sum(glszm_new, (1, 2))  # shape (Nvox,)
        Nz_new[Nz_new == 0] = 1  # set sum to numpy.spacing(1) if sum is 0?

        # Get the number of voxels represented by this GLSZM: Multiply the zones by their size and sum them
        Np_new = np.sum(ps_new * jv_new[None, :], 1)  # shape (Nvox, )
        Np_new[Np_new == 0] = 1

        # Get the pg
        glszm_2d_new = glszm_new[0, 0:s_new[1], 0:s_new[2]]
        pg_reshape = np.sum(glszm_2d_new, 1)
        pg_new = np.reshape(pg_reshape, (1,s_new[1]))

    else:

        #just crab the coeffiecients as usual
        iv_new = iv_org
        jv_new = jv_org
        glszm_new = glszm_org
        Nz_new = glszmFeatures.coefficients['Nz']
        Np_new = glszmFeatures.coefficients['Np']
        pg_new = glszmFeatures.coefficients['pg']
        ps_new = glszmFeatures.coefficients['ps']

    jvector = jv_new
    ivector = iv_new
    ps = ps_new
    pg = pg_new
    Np = Np_new
    Nz = Nz_new
    pg_norm = pg/Nz[:, None]
    ps_norm = ps/Nz[:, None]
    eps = np.spacing(1)
    glszm = glszm_new
    print('The shape of the old glszm is', str(glszm_org.shape), '. The shape of the new glszm is', str(glszm.shape))
    glszm_norm = glszm_new/Nz[:, None, None]

    print("GLSZM processing complete ...")

    #Calculate glszm features and normalize the features
    print("Initiating GLSZM feature calculation...... ")

    sae = np.sum(ps / (jvector[None, :] ** 2), 1) / Nz #small area emphaisis
    sae = sae.astype(float)
    lae = np.sum(ps * (jvector[None, :] ** 2), 1) / Nz #large area emphaisis
    iv = np.sum(pg ** 2, 1) / Nz #graylevel non-uniformity
    ivn = np.sum(pg ** 2, 1) / Nz ** 2 #graylevel non-uniformity normalized
    szv = np.sum(ps ** 2, 1) / Nz #size zone uniformity
    szvn = np.sum(ps ** 2, 1) / Nz ** 2 #size zone uniformity normalised
    zp = Nz / Np # zone percentage
    u_i = np.sum(pg_norm * ivector[None, :], 1, keepdims=True) # mean calculation for graylevel variance
    glv = np.sum(pg_norm * (ivector[None, :] - u_i) ** 2, 1) # graylevel variance
    u_j = np.sum(ps_norm * jvector[None, :], 1, keepdims=True) #mean caluclation of zone variance
    zv = np.sum(ps_norm * (jvector[None, :] - u_j) ** 2, 1) #zone variance
    ze = -np.sum(glszm_norm * np.log2(glszm_norm + eps), (1, 2)) #zone entropy
    lie = np.sum(pg / (ivector[None, :] ** 2), 1) / Nz #Low graylevel zone emphaisis
    hie = np.sum(pg * (ivector[None, :] ** 2), 1) / Nz #high graylevel zone emphaisis
    lisae = np.sum(glszm / ((ivector[None, :, None] ** 2) * (jvector[None, None, :] ** 2)), (1, 2)) / Nz #small area low graylevel emphaisis
    hisae = np.sum(glszm * (ivector[None, :, None] ** 2) / (jvector[None, None, :] ** 2), (1, 2)) / Nz #small area high graylevel emphaisis
    lilae = np.sum(glszm * (jvector[None, None, :] ** 2) / (ivector[None, :, None] ** 2), (1, 2)) / Nz #large area low gray level emphaisis
    hilae = np.sum(glszm * (ivector[None, :, None] ** 2) * (jvector[None, None, :] ** 2), (1, 2)) / Nz #large area high gray level emphaisis

    #append values
    v1.append(iv[0])
    v2.append(ivn[0])
    v3.append(glv[0])
    v4.append(hie[0])
    v5.append(lae[0])
    v6.append(hilae[0])
    v7.append(lilae[0])
    v8.append(lie[0])
    v9.append(szv[0])
    v10.append(szvn[0])
    v11.append(sae[0])
    v12.append(hisae[0])
    v13.append(lisae[0])
    v14.append(ze[0])
    v15.append(zp[0])
    v16.append(zv[0])

# %% [markdown]
# ##### Window calculations

# %%
# %%time
print("Starting the automation loop for GLSZM feature extraction")

# All the greyscale images of various porous media types are named as data#.nrrd. 

    
# Create the variables for image and label
global image_1, label_1

# Path of the images used in REV analysis
path ='D:\\Joost\\GREV-PorousMedia\\example\\data\\example_data.nrrd'

# Read the nrrd image using the SITK library. Nrrd images are 8-bit images with intensity values between 0 to 255
image_1 = sitk.ReadImage(path) 

# Set the settings paramter needed  for the bin_width and label
# Bin_Width = 1 (as I don't want any further reduction in greyscale values and want to preserve the information)
# label is a nrrd image that incorporates the window size and hence, gives a ROI for the GLSZM calculation.
# The minimum size is set by the user and the mavimum size is the size of the image
settings = {}
settings['label'] = 255
settings['binWidth'] = 1

# the size of the mask (same as label) should be the same as that of the image
mask_x = image_1.GetWidth()
mask_y = image_1.GetWidth()
mask_z = image_1.GetWidth()

print("Initializing window calculcations for image")

# here the window_size refers to the region of mask that will be used to segment the ROI from the image. The window
# sizes decreases with every iteration
u_window_size = [20, 40, 60, 80, 100, 120, 140, 160, 180, 200]  

step = 20
global window_size, total_iter, expect_iter, i_loc, j_loc, z_loc, bb, correctedMask, croppedImage, croppedMask, glcm_window
global v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11, v12, v13, v14, v15, v16

for window_size in u_window_size:  

    print("Starting the window calculcation for image for window size = ", str(window_size)) 
    total_iter = 0

    v1 = []    
    v2 = []
    v3 = []
    v4 = []
    v5 = []
    v6 = []
    v7 = []
    v8 = []
    v9 = []
    v10 = []
    v11 = []
    v12 = []
    v13 = []
    v14 = []
    v15 = []
    v16 = []

    i_loc=0
    j_loc=0
    z_loc=0
    i_loc_max = window_size
    j_loc_max = window_size
    z_loc_max = window_size


    # x-direction
    while i_loc_max <= mask_x and total_iter < 2000:

        #y-direction
        j_loc_max = window_size
        while j_loc_max <= mask_y and total_iter < 2000:

            #z-direction
            z_loc_max = window_size
            while z_loc_max <= mask_z and total_iter < 2000:

                full_mask = np.zeros((mask_x, mask_y, mask_z), dtype = np.uint8)
                full_mask[i_loc:i_loc_max,j_loc:j_loc_max,z_loc:z_loc_max] = 255
                print(str(full_mask.size))

                label_1 = sitk.GetImageFromArray(full_mask, isVector=False)
                label_1.CopyInformation(image_1)
                del full_mask

                bb, correctedMask = imageoperations.checkMask(image_1, label_1, label=255)
                if correctedMask is not None:
                    label_1 = correctedMask
                croppedImage, croppedMask = imageoperations.cropToTumorMask(image_1, label_1, bb)
                del correctedMask, label_1

                glszm_calculations()

                z_loc = z_loc + step
                total_iter = total_iter + 1
                #print(total_iter)
                z_loc_max = z_loc + window_size

            z_loc = 0
            j_loc = j_loc + step
            j_loc_max = j_loc+ window_size

        j_loc = 0
        i_loc = i_loc + step
        i_loc_max = i_loc + window_size

    print("Completed Calculations for Window ", str(window_size), ". The number of iterations is ", str(total_iter))     

    w1 = [window_size] * total_iter
    # Create a data-frame to store all the GLSZM features for the image        
    my_df = pd.DataFrame(list(zip(w1, v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11, v12, v13, v14, v15, v16)))
    my_df = my_df.rename(index = str, columns={0: "Window Sizes", 1: "GrayLevelNonUniformity", 2: "GrayLevelNonUniformityNormalized", \
                               3: "GrayLevelVariance", 4: "HighGrayLevelZoneEmphasis", 5: "LargeAreaEmphasis", \
                               6: "LargeAreaHighGrayLevelEmphasis", 7: "LargeAreaLowGrayLevelEmphasis", 8: "LowGrayLevelZoneEmphasis", \
                               9: "SizeZoneNonUniformity", 10: "SizeZoneNonUniformityNormalized", 11: "SmallAreaEmphasis", \
                               12: "SmallAreaHighGrayLevelEmphasis", 13: "SmallAreaLowGrayLevelEmphasis", 14: "ZoneEntropy", \
                               15: "ZonePercentage", 16: "ZoneVariance"})    


    name_csv = 'D:\\Joost\\GREV-PorousMedia\\example\\glszm_example_data_w{}.csv'.format(window_size)
    my_df.to_csv(name_csv, index=False, header=True)

    print("Saved glcm values of window size ", str(window_size))
# Out:
# Starting the automation loop for GLSZM feature extraction
# Initializing window calculcations for image
# Starting the window calculcation for image for window size =  20
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 199, 18) . The shape of the new glszm is (1, 199, 18)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 202, 18) . The shape of the new glszm is (1, 202, 18)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 209, 20) . The shape of the new glszm is (1, 209, 20)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 168, 25) . The shape of the new glszm is (1, 168, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 159, 30) . The shape of the new glszm is (1, 159, 30)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 178, 20) . The shape of the new glszm is (1, 178, 20)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 75, 33) . The shape of the new glszm is (1, 75, 33)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 172, 31) . The shape of the new glszm is (1, 172, 31)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 194, 25) . The shape of the new glszm is (1, 193, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 219, 26) . The shape of the new glszm is (1, 218, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 24) . The shape of the new glszm is (1, 173, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 180, 20) . The shape of the new glszm is (1, 180, 20)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 178, 24) . The shape of the new glszm is (1, 178, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 170, 19) . The shape of the new glszm is (1, 170, 19)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 176, 27) . The shape of the new glszm is (1, 176, 27)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 169, 26) . The shape of the new glszm is (1, 169, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 170, 28) . The shape of the new glszm is (1, 170, 28)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 169, 28) . The shape of the new glszm is (1, 169, 28)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 170, 20) . The shape of the new glszm is (1, 170, 20)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 22) . The shape of the new glszm is (1, 173, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 167, 21) . The shape of the new glszm is (1, 167, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 162, 30) . The shape of the new glszm is (1, 162, 30)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 175, 23) . The shape of the new glszm is (1, 175, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 179, 26) . The shape of the new glszm is (1, 179, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 182, 23) . The shape of the new glszm is (1, 182, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 160, 24) . The shape of the new glszm is (1, 160, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 134, 28) . The shape of the new glszm is (1, 134, 28)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 54, 30) . The shape of the new glszm is (1, 54, 30)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 71, 31) . The shape of the new glszm is (1, 71, 31)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 164, 23) . The shape of the new glszm is (1, 164, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 178, 23) . The shape of the new glszm is (1, 178, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 174, 29) . The shape of the new glszm is (1, 174, 29)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 23) . The shape of the new glszm is (1, 171, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 177, 25) . The shape of the new glszm is (1, 177, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 20) . The shape of the new glszm is (1, 171, 20)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 23) . The shape of the new glszm is (1, 171, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 20) . The shape of the new glszm is (1, 171, 20)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 179, 26) . The shape of the new glszm is (1, 179, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 175, 22) . The shape of the new glszm is (1, 175, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 170, 22) . The shape of the new glszm is (1, 170, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 193, 25) . The shape of the new glszm is (1, 192, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 175, 24) . The shape of the new glszm is (1, 175, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 174, 21) . The shape of the new glszm is (1, 174, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 177, 18) . The shape of the new glszm is (1, 177, 18)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 178, 21) . The shape of the new glszm is (1, 178, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 163, 24) . The shape of the new glszm is (1, 163, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 127, 28) . The shape of the new glszm is (1, 127, 28)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 152, 30) . The shape of the new glszm is (1, 152, 30)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 164, 24) . The shape of the new glszm is (1, 164, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 168, 22) . The shape of the new glszm is (1, 168, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 172, 26) . The shape of the new glszm is (1, 171, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 26) . The shape of the new glszm is (1, 173, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 176, 24) . The shape of the new glszm is (1, 176, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 20) . The shape of the new glszm is (1, 173, 20)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 167, 19) . The shape of the new glszm is (1, 167, 19)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 168, 23) . The shape of the new glszm is (1, 168, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 72, 28) . The shape of the new glszm is (1, 72, 28)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 172, 18) . The shape of the new glszm is (1, 172, 18)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 169, 22) . The shape of the new glszm is (1, 169, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 18) . The shape of the new glszm is (1, 173, 18)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 166, 22) . The shape of the new glszm is (1, 166, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 154, 33) . The shape of the new glszm is (1, 154, 33)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 27) . The shape of the new glszm is (1, 173, 27)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 172, 23) . The shape of the new glszm is (1, 172, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 168, 22) . The shape of the new glszm is (1, 168, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 161, 25) . The shape of the new glszm is (1, 161, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 168, 23) . The shape of the new glszm is (1, 168, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 169, 32) . The shape of the new glszm is (1, 169, 32)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 167, 25) . The shape of the new glszm is (1, 167, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 166, 25) . The shape of the new glszm is (1, 166, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 172, 25) . The shape of the new glszm is (1, 172, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 170, 27) . The shape of the new glszm is (1, 170, 27)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 170, 20) . The shape of the new glszm is (1, 170, 20)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 22) . The shape of the new glszm is (1, 173, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 188, 24) . The shape of the new glszm is (1, 188, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 172, 20) . The shape of the new glszm is (1, 172, 20)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 196, 25) . The shape of the new glszm is (1, 196, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 174, 25) . The shape of the new glszm is (1, 174, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 177, 26) . The shape of the new glszm is (1, 177, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 165, 18) . The shape of the new glszm is (1, 165, 18)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 23) . The shape of the new glszm is (1, 171, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 166, 25) . The shape of the new glszm is (1, 166, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 22) . The shape of the new glszm is (1, 173, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 170, 21) . The shape of the new glszm is (1, 170, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 22) . The shape of the new glszm is (1, 171, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 166, 24) . The shape of the new glszm is (1, 166, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 174, 22) . The shape of the new glszm is (1, 174, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 175, 20) . The shape of the new glszm is (1, 175, 20)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 176, 23) . The shape of the new glszm is (1, 176, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 175, 23) . The shape of the new glszm is (1, 175, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 23) . The shape of the new glszm is (1, 173, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 180, 21) . The shape of the new glszm is (1, 180, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 142, 30) . The shape of the new glszm is (1, 142, 30)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 23) . The shape of the new glszm is (1, 171, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 169, 22) . The shape of the new glszm is (1, 169, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 178, 28) . The shape of the new glszm is (1, 178, 28)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 170, 26) . The shape of the new glszm is (1, 170, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 179, 22) . The shape of the new glszm is (1, 179, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 197, 24) . The shape of the new glszm is (1, 197, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 169, 24) . The shape of the new glszm is (1, 169, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 176, 24) . The shape of the new glszm is (1, 176, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 167, 20) . The shape of the new glszm is (1, 167, 20)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 163, 24) . The shape of the new glszm is (1, 163, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 169, 18) . The shape of the new glszm is (1, 169, 18)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 165, 22) . The shape of the new glszm is (1, 165, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 161, 25) . The shape of the new glszm is (1, 161, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 165, 24) . The shape of the new glszm is (1, 165, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 21) . The shape of the new glszm is (1, 173, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 25) . The shape of the new glszm is (1, 171, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 170, 22) . The shape of the new glszm is (1, 170, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 172, 19) . The shape of the new glszm is (1, 172, 19)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 184, 21) . The shape of the new glszm is (1, 184, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 72, 32) . The shape of the new glszm is (1, 72, 32)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 177, 24) . The shape of the new glszm is (1, 177, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 21) . The shape of the new glszm is (1, 173, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 178, 16) . The shape of the new glszm is (1, 178, 16)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 175, 23) . The shape of the new glszm is (1, 175, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 186, 16) . The shape of the new glszm is (1, 186, 16)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 20) . The shape of the new glszm is (1, 173, 20)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 180, 21) . The shape of the new glszm is (1, 180, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 176, 26) . The shape of the new glszm is (1, 176, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 168, 26) . The shape of the new glszm is (1, 168, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 182, 19) . The shape of the new glszm is (1, 182, 19)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 179, 28) . The shape of the new glszm is (1, 179, 28)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 172, 26) . The shape of the new glszm is (1, 172, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 178, 24) . The shape of the new glszm is (1, 178, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 175, 24) . The shape of the new glszm is (1, 175, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 175, 23) . The shape of the new glszm is (1, 175, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 170, 28) . The shape of the new glszm is (1, 170, 28)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 172, 23) . The shape of the new glszm is (1, 172, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 176, 26) . The shape of the new glszm is (1, 176, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 169, 23) . The shape of the new glszm is (1, 169, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 176, 25) . The shape of the new glszm is (1, 176, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 28) . The shape of the new glszm is (1, 171, 28)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 176, 28) . The shape of the new glszm is (1, 176, 28)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 25) . The shape of the new glszm is (1, 173, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 172, 19) . The shape of the new glszm is (1, 172, 19)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 226, 22) . The shape of the new glszm is (1, 225, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 184, 27) . The shape of the new glszm is (1, 184, 27)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 178, 19) . The shape of the new glszm is (1, 178, 19)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 121, 33) . The shape of the new glszm is (1, 121, 33)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 176, 20) . The shape of the new glszm is (1, 176, 20)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 176, 25) . The shape of the new glszm is (1, 176, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 174, 21) . The shape of the new glszm is (1, 174, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 172, 22) . The shape of the new glszm is (1, 172, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 24) . The shape of the new glszm is (1, 173, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 177, 24) . The shape of the new glszm is (1, 177, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 168, 22) . The shape of the new glszm is (1, 168, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 19) . The shape of the new glszm is (1, 171, 19)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 169, 23) . The shape of the new glszm is (1, 169, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 164, 27) . The shape of the new glszm is (1, 164, 27)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 170, 19) . The shape of the new glszm is (1, 170, 19)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 174, 22) . The shape of the new glszm is (1, 174, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 177, 23) . The shape of the new glszm is (1, 177, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 181, 17) . The shape of the new glszm is (1, 181, 17)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 175, 19) . The shape of the new glszm is (1, 175, 19)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 167, 23) . The shape of the new glszm is (1, 167, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 175, 25) . The shape of the new glszm is (1, 175, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 169, 25) . The shape of the new glszm is (1, 169, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 25) . The shape of the new glszm is (1, 171, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 170, 27) . The shape of the new glszm is (1, 170, 27)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 162, 29) . The shape of the new glszm is (1, 162, 29)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 166, 24) . The shape of the new glszm is (1, 166, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 168, 19) . The shape of the new glszm is (1, 168, 19)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 163, 26) . The shape of the new glszm is (1, 163, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 167, 27) . The shape of the new glszm is (1, 167, 27)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 27) . The shape of the new glszm is (1, 171, 27)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 180, 19) . The shape of the new glszm is (1, 180, 19)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 160, 25) . The shape of the new glszm is (1, 160, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 178, 18) . The shape of the new glszm is (1, 178, 18)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 167, 21) . The shape of the new glszm is (1, 167, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 180, 19) . The shape of the new glszm is (1, 180, 19)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 27) . The shape of the new glszm is (1, 171, 27)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 21) . The shape of the new glszm is (1, 171, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 168, 27) . The shape of the new glszm is (1, 168, 27)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 148, 30) . The shape of the new glszm is (1, 148, 30)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 151, 28) . The shape of the new glszm is (1, 151, 28)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 164, 23) . The shape of the new glszm is (1, 164, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 18) . The shape of the new glszm is (1, 173, 18)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 136, 32) . The shape of the new glszm is (1, 136, 32)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 167, 21) . The shape of the new glszm is (1, 167, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 172, 21) . The shape of the new glszm is (1, 172, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 179, 24) . The shape of the new glszm is (1, 179, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 149, 27) . The shape of the new glszm is (1, 149, 27)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 166, 25) . The shape of the new glszm is (1, 166, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 175, 23) . The shape of the new glszm is (1, 175, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 168, 25) . The shape of the new glszm is (1, 168, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 18) . The shape of the new glszm is (1, 173, 18)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 166, 26) . The shape of the new glszm is (1, 166, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 147, 29) . The shape of the new glszm is (1, 147, 29)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 29) . The shape of the new glszm is (1, 171, 29)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 182, 29) . The shape of the new glszm is (1, 182, 29)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 169, 21) . The shape of the new glszm is (1, 169, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 168, 23) . The shape of the new glszm is (1, 168, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 165, 27) . The shape of the new glszm is (1, 165, 27)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 165, 19) . The shape of the new glszm is (1, 165, 19)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 163, 29) . The shape of the new glszm is (1, 163, 29)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 174, 22) . The shape of the new glszm is (1, 174, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 165, 22) . The shape of the new glszm is (1, 165, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 164, 30) . The shape of the new glszm is (1, 164, 30)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 117, 29) . The shape of the new glszm is (1, 117, 29)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 176, 23) . The shape of the new glszm is (1, 176, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 172, 29) . The shape of the new glszm is (1, 172, 29)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 178, 22) . The shape of the new glszm is (1, 178, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 169, 22) . The shape of the new glszm is (1, 169, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 158, 29) . The shape of the new glszm is (1, 158, 29)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 175, 21) . The shape of the new glszm is (1, 175, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 26) . The shape of the new glszm is (1, 171, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 181, 19) . The shape of the new glszm is (1, 181, 19)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 22) . The shape of the new glszm is (1, 173, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 177, 26) . The shape of the new glszm is (1, 177, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 174, 26) . The shape of the new glszm is (1, 174, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 25) . The shape of the new glszm is (1, 173, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 182, 25) . The shape of the new glszm is (1, 182, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 165, 24) . The shape of the new glszm is (1, 165, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 172, 26) . The shape of the new glszm is (1, 172, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 157, 20) . The shape of the new glszm is (1, 157, 20)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 168, 23) . The shape of the new glszm is (1, 168, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 178, 19) . The shape of the new glszm is (1, 178, 19)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 184, 19) . The shape of the new glszm is (1, 184, 19)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 193, 17) . The shape of the new glszm is (1, 193, 17)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 178, 24) . The shape of the new glszm is (1, 178, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 188, 21) . The shape of the new glszm is (1, 188, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 162, 30) . The shape of the new glszm is (1, 162, 30)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 163, 25) . The shape of the new glszm is (1, 163, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 169, 21) . The shape of the new glszm is (1, 169, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 177, 23) . The shape of the new glszm is (1, 177, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 173, 23) . The shape of the new glszm is (1, 173, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 175, 22) . The shape of the new glszm is (1, 175, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 176, 27) . The shape of the new glszm is (1, 176, 27)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 188, 13) . The shape of the new glszm is (1, 188, 13)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 194, 19) . The shape of the new glszm is (1, 194, 19)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 188, 21) . The shape of the new glszm is (1, 188, 21)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 28) . The shape of the new glszm is (1, 171, 28)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 175, 25) . The shape of the new glszm is (1, 175, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 25) . The shape of the new glszm is (1, 171, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 162, 23) . The shape of the new glszm is (1, 162, 23)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 158, 29) . The shape of the new glszm is (1, 158, 29)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 164, 27) . The shape of the new glszm is (1, 164, 27)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 172, 22) . The shape of the new glszm is (1, 172, 22)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 186, 16) . The shape of the new glszm is (1, 186, 16)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 199, 13) . The shape of the new glszm is (1, 199, 13)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 201, 15) . The shape of the new glszm is (1, 201, 15)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 168, 26) . The shape of the new glszm is (1, 168, 26)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 167, 25) . The shape of the new glszm is (1, 167, 25)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 171, 20) . The shape of the new glszm is (1, 171, 20)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# The shape of the old glszm is (1, 168, 24) . The shape of the new glszm is (1, 168, 24)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# ...
# The shape of the old glszm is (1, 250, 90) . The shape of the new glszm is (1, 249, 88)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 248, 91) . The shape of the new glszm is (1, 247, 89)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 247, 92) . The shape of the new glszm is (1, 246, 91)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 247, 91) . The shape of the new glszm is (1, 246, 89)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 249, 95) . The shape of the new glszm is (1, 248, 93)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 247, 96) . The shape of the new glszm is (1, 246, 94)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 246, 93) . The shape of the new glszm is (1, 245, 92)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 247, 90) . The shape of the new glszm is (1, 246, 88)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 251, 90) . The shape of the new glszm is (1, 250, 88)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 249, 91) . The shape of the new glszm is (1, 248, 89)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 249, 91) . The shape of the new glszm is (1, 248, 90)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 247, 91) . The shape of the new glszm is (1, 246, 90)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 250, 92) . The shape of the new glszm is (1, 249, 90)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 248, 90) . The shape of the new glszm is (1, 247, 89)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 247, 90) . The shape of the new glszm is (1, 246, 89)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 247, 92) . The shape of the new glszm is (1, 246, 90)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 250, 91) . The shape of the new glszm is (1, 249, 88)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 248, 92) . The shape of the new glszm is (1, 247, 89)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 247, 91) . The shape of the new glszm is (1, 246, 89)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 247, 92) . The shape of the new glszm is (1, 246, 89)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 249, 97) . The shape of the new glszm is (1, 248, 94)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 247, 97) . The shape of the new glszm is (1, 246, 94)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 246, 91) . The shape of the new glszm is (1, 245, 89)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 245, 92) . The shape of the new glszm is (1, 244, 89)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# Completed Calculations for Window  140 . The number of iterations is  64
# Saved glcm values of window size  140
# Starting the window calculcation for image for window size =  160
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 250, 97) . The shape of the new glszm is (1, 249, 96)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 248, 97) . The shape of the new glszm is (1, 247, 97)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 248, 98) . The shape of the new glszm is (1, 247, 97)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 250, 98) . The shape of the new glszm is (1, 249, 97)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 248, 97) . The shape of the new glszm is (1, 247, 97)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 248, 98) . The shape of the new glszm is (1, 247, 98)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 249, 100) . The shape of the new glszm is (1, 248, 99)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 247, 98) . The shape of the new glszm is (1, 246, 98)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 247, 98) . The shape of the new glszm is (1, 246, 98)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 251, 99) . The shape of the new glszm is (1, 250, 97)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 249, 100) . The shape of the new glszm is (1, 248, 98)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 249, 99) . The shape of the new glszm is (1, 248, 97)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 251, 101) . The shape of the new glszm is (1, 250, 98)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 249, 99) . The shape of the new glszm is (1, 248, 97)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 248, 99) . The shape of the new glszm is (1, 247, 97)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 250, 102) . The shape of the new glszm is (1, 249, 99)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 248, 100) . The shape of the new glszm is (1, 247, 98)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 247, 99) . The shape of the new glszm is (1, 246, 97)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 251, 97) . The shape of the new glszm is (1, 250, 95)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 249, 98) . The shape of the new glszm is (1, 248, 96)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 249, 97) . The shape of the new glszm is (1, 248, 95)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 251, 102) . The shape of the new glszm is (1, 250, 98)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 249, 99) . The shape of the new glszm is (1, 248, 96)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 248, 99) . The shape of the new glszm is (1, 247, 96)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 250, 104) . The shape of the new glszm is (1, 249, 100)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 248, 100) . The shape of the new glszm is (1, 247, 97)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 247, 99) . The shape of the new glszm is (1, 246, 96)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# Completed Calculations for Window  160 . The number of iterations is  27
# Saved glcm values of window size  160
# Starting the window calculcation for image for window size =  180
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 251, 105) . The shape of the new glszm is (1, 250, 103)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 249, 103) . The shape of the new glszm is (1, 248, 101)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 251, 108) . The shape of the new glszm is (1, 250, 106)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 249, 104) . The shape of the new glszm is (1, 248, 103)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 251, 106) . The shape of the new glszm is (1, 250, 102)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 249, 103) . The shape of the new glszm is (1, 248, 100)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 251, 108) . The shape of the new glszm is (1, 250, 104)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 249, 105) . The shape of the new glszm is (1, 248, 102)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# Completed Calculations for Window  180 . The number of iterations is  8
# Saved glcm values of window size  180
# Starting the window calculcation for image for window size =  200
# 8000000
# Calculated GLSZM.....
# Mineral phase is present because the graylevel of 256.0 exists.
# The shape of the old glszm is (1, 251, 113) . The shape of the new glszm is (1, 250, 109)
# GLSZM processing complete ...
# Initiating GLSZM feature calculation......
# Completed Calculations for Window  200 . The number of iterations is  1
# Saved glcm values of window size  200
# Wall time: 14min 34s
